# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
#read in data (assumes csv is in same folder as this notebook)
data = pd.read_csv('star_classification.csv')
data.shape
# Out:
# (100000, 18)

# %%
data.head()
# Out:
#          obj_ID       alpha      delta         u         g         r  \
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# 1  GALAXY  0.779136  10445  58158       427
# 2  GALAXY  0.644195   4576  55592       299
# 3  GALAXY  0.932346   9149  58039       775
# 4  GALAXY  0.116123   6121  56187       842

# %%
data_dictionary = {
    'obj_ID':'Object Identifier', 
    'alpha':'Right Ascension:the astronomical equivalent of longitude. Right ascension is the angular distance ofan object measured eastward from the First Point of Aries, also called the Vernal Equinox', 
    'delta': 'Declination: the astronomical equivalent of latitude. Declination is an angular distance of a pointnorth or south of the Celestial Equator, a projection of the Earth’s equator into space. Declination is measured in degrees from -90° to +90°.',
    'u': 'Ultraviolet, Effective Wavelength Midpoint λ(eff) = 365nm',
    'g': 'Green, Effective Wavelength Midpoint λ(eff) = 464nm',
    'r': 'Red, Effective Wavelength Midpoint λ(eff) = 658nm',
    'i': 'Infrared, Effective Wavelength Midpoint λ(eff) = 806nm',
    'z': 'Z, Effective Wavelength Midpoint λ(eff) = 900nm',
    'run_ID': 'Run Number',
    'rerun_ID': 'Rerun Number',
    'cam_col': 'Camera Column',
    'field_ID':'Field Number',
    'spec_obj_ID':'Object Identifier',
    'class': 'Output Class',
    'redshift': 'Red shift is a key concept for astronomers. The term can be understood literally - the wavelength of the light is stretched, so the light is seen as shifted towards the red part of the spectrum.',
    'plate': 'Plate Number',
    'MJD': 'Modified Julian Date',
    'fiber_ID': 'fiber ID'
    }

# %% [markdown]
# #### Photometric Letters
#
# Each letter designates a section of light of the electromagnetic spectrum; these cover well the consecutive major groups, near-ultraviolet (NUV), visible light (centered on the V band), near-infrared (NIR) and part of mid-infrared (MIR).[a]
#
# The letters are not standards, but are recognized by common agreement among astronomers and astrophysicists.
#
# The use of U,B,V,R,I bands dates from the 1950s, being single-letter abbreviations.[b] With the advent of infrared detectors in the next decade, the J to N bands were labelled following on from near-infrared's closest-to-red band, I. Later the H band was inserted, then Z in the 1990s and finally Y, without changing earlier definitions. Hence, H is out of alphabetical order from its neighbours, while Z,Y are reversed from the alphabetical – higher-wavelength – sub-series which dominates current photometric bands.

# %%
display(data.describe())
display(data.info())
# Out:
#              obj_ID          alpha          delta              u  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# 25%        18.965230      18.135828      17.732285      17.460677
# 50%        21.099835      20.125290      19.405145      19.004595
# 75%        22.123767      21.044785      20.396495      19.921120
# max        31.602240      29.571860      32.141470      29.383740
#
#               run_ID  rerun_ID        cam_col       field_ID   spec_obj_ID  \
# count  100000.000000  100000.0  100000.000000  100000.000000  1.000000e+05
# mean     4481.366060     301.0       3.511610     186.130520  5.783882e+18
# std      1964.764593       0.0       1.586912     149.011073  3.324016e+18
# min       109.000000     301.0       1.000000      11.000000  2.995191e+17
# 25%      3187.000000     301.0       2.000000      82.000000  2.844138e+18
# 50%      4188.000000     301.0       4.000000     146.000000  5.614883e+18
# 75%      5326.000000     301.0       5.000000     241.000000  8.332144e+18
# max      8162.000000     301.0       6.000000     989.000000  1.412694e+19
#
#             redshift          plate            MJD       fiber_ID
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.576661    5137.009660   55588.647500     449.312740
# std         0.730707    2952.303351    1808.484233     272.498404
# min        -0.009971     266.000000   51608.000000       1.000000
# 25%         0.054517    2526.000000   54234.000000     221.000000
# 50%         0.424173    4987.000000   55868.500000     433.000000
# 75%         0.704154    7400.250000   56777.000000     645.000000
# max         7.011245   12547.000000   58932.000000    1000.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 13.7+ MB
# None

# %%
#Drop ID related columns
id_cols = ['rerun_ID','obj_ID','run_ID','field_ID','fiber_ID','spec_obj_ID']
data = data.drop(id_cols, axis = 1)

# %%
data.hist(figsize=(18,12))
# Out:
# array([[<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'delta'}>,
#         <AxesSubplot:title={'center':'u'}>],
#        [<AxesSubplot:title={'center':'g'}>,
#         <AxesSubplot:title={'center':'r'}>,
#         <AxesSubplot:title={'center':'i'}>],
#        [<AxesSubplot:title={'center':'z'}>,
#         <AxesSubplot:title={'center':'cam_col'}>,
#         <AxesSubplot:title={'center':'redshift'}>],
#        [<AxesSubplot:title={'center':'plate'}>,
#         <AxesSubplot:title={'center':'MJD'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_35680_row0_col0, #T_35680_row1_col1, #T_35680_row2_col2, #T_35680_row2_col3, #T_35680_row2_col6, #T_35680_row3_col2, #T_35680_row3_col3, #T_35680_row3_col6, #T_35680_row4_col4, #T_35680_row5_col5, #T_35680_row6_col2, #T_35680_row6_col3, #T_35680_row6_col6, #T_35680_row7_col7, #T_35680_row8_col8, #T_35680_row9_col9, #T_35680_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_35680_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_35680_row0_col2, #T_35680_row0_col3, #T_35680_row0_col4, #T_35680_row0_col5, #T_35680_row0_col6, #T_35680_row0_col8, #T_35680_row0_col9, #T_35680_row1_col2, #T_35680_row4_col0, #T_35680_row4_col1, #T_35680_row5_col0, #T_35680_row5_col1, #T_35680_row7_col8, #T_35680_row7_col9, #T_35680_row7_col10, #T_35680_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_35680_row0_col7, #T_35680_row0_col10, #T_35680_row8_col0, #T_35680_row8_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_35680_row1_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_35680_row1_col3, #T_35680_row1_col6, #T_35680_row7_col2, #T_35680_row7_col3, #T_35680_row7_col6, #T_35680_row8_col7, #T_35680_row9_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_35680_row1_col4, #T_35680_row2_col8, #T_35680_row4_col7, #T_35680_row5_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_35680_row1_col5, #T_35680_row8_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_35680_row1_col7, #T_35680_row2_col10, #T_35680_row8_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_35680_row1_col8, #T_35680_row2_col9, #T_35680_row8_col6, #T_35680_row9_col2, #T_35680_row10_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_35680_row1_col9, #T_35680_row1_col10, #T_35680_row10_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_35680_row2_col0, #T_35680_row3_col0, #T_35680_row3_col8, #T_35680_row6_col0, #T_35680_row9_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_35680_row2_col1, #T_35680_row2_col7, #T_35680_row3_col1, #T_35680_row3_col7, #T_35680_row6_col1, #T_35680_row6_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_35680_row2_col4, #T_35680_row3_col5, #T_35680_row6_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_35680_row2_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_35680_row3_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_35680_row3_col9, #T_35680_row6_col9, #T_35680_row7_col0, #T_35680_row7_col1, #T_35680_row9_col3, #T_35680_row9_col6, #T_35680_row10_col0, #T_35680_row10_col3, #T_35680_row10_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_35680_row3_col10, #T_35680_row6_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_35680_row4_col2, #T_35680_row4_col6, #T_35680_row5_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_35680_row4_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_35680_row4_col5, #T_35680_row5_col4 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_35680_row4_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_35680_row4_col9 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_35680_row4_col10, #T_35680_row5_col10 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_35680_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_35680_row5_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_35680_row5_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_35680_row5_col9, #T_35680_row9_col4 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_35680_row6_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_35680_row6_col8, #T_35680_row7_col4, #T_35680_row7_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_35680_row8_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_35680_row8_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_35680_row8_col9, #T_35680_row9_col8, #T_35680_row10_col8 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_35680_row8_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_35680_row9_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_35680_row9_col5 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_35680_row9_col10, #T_35680_row10_col9 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_35680_row10_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_35680_row10_col5 {
#   background-color: #f7b396;
#   color: #000000;
# }
# </style>
# <table id="T_35680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35680_level0_col0" class="col_heading level0 col0" >alpha</th>
#       <th id="T_35680_level0_col1" class="col_heading level0 col1" >delta</th>
#       <th id="T_35680_level0_col2" class="col_heading level0 col2" >u</th>
#       <th id="T_35680_level0_col3" class="col_heading level0 col3" >g</th>
#       <th id="T_35680_level0_col4" class="col_heading level0 col4" >r</th>
#       <th id="T_35680_level0_col5" class="col_heading level0 col5" >i</th>
#       <th id="T_35680_level0_col6" class="col_heading level0 col6" >z</th>
#       <th id="T_35680_level0_col7" class="col_heading level0 col7" >cam_col</th>
#       <th id="T_35680_level0_col8" class="col_heading level0 col8" >redshift</th>
#       <th id="T_35680_level0_col9" class="col_heading level0 col9" >plate</th>
#       <th id="T_35680_level0_col10" class="col_heading level0 col10" >MJD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35680_level0_row0" class="row_heading level0 row0" >alpha</th>
#       <td id="T_35680_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_35680_row0_col1" class="data row0 col1" >0.138691</td>
#       <td id="T_35680_row0_col2" class="data row0 col2" >-0.001532</td>
#       <td id="T_35680_row0_col3" class="data row0 col3" >-0.002423</td>
#       <td id="T_35680_row0_col4" class="data row0 col4" >-0.022083</td>
#       <td id="T_35680_row0_col5" class="data row0 col5" >-0.023580</td>
#       <td id="T_35680_row0_col6" class="data row0 col6" >-0.002918</td>
#       <td id="T_35680_row0_col7" class="data row0 col7" >0.019582</td>
#       <td id="T_35680_row0_col8" class="data row0 col8" >0.001667</td>
#       <td id="T_35680_row0_col9" class="data row0 col9" >-0.002554</td>
#       <td id="T_35680_row0_col10" class="data row0 col10" >0.019943</td>
#     </tr>
#     <tr>
#       <th id="T_35680_level0_row1" class="row_heading level0 row1" >delta</th>
#       <td id="T_35680_row1_col0" class="data row1 col0" >0.138691</td>
#       <td id="T_35680_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_35680_row1_col2" class="data row1 col2" >0.002074</td>
#       <td id="T_35680_row1_col3" class="data row1 col3" >0.003523</td>
#       <td id="T_35680_row1_col4" class="data row1 col4" >-0.006835</td>
#       <td id="T_35680_row1_col5" class="data row1 col5" >-0.004480</td>
#       <td id="T_35680_row1_col6" class="data row1 col6" >0.003630</td>
#       <td id="T_35680_row1_col7" class="data row1 col7" >0.032565</td>
#       <td id="T_35680_row1_col8" class="data row1 col8" >0.031638</td>
#       <td id="T_35680_row1_col9" class="data row1 col9" >0.112329</td>
#       <td id="T_35680_row1_col10" class="data row1 col10" >0.107333</td>
#     </tr>
#     <tr>
#       <th id="T_35680_level0_row2" class="row_heading level0 row2" >u</th>
#       <td id="T_35680_row2_col0" class="data row2 col0" >-0.001532</td>
#       <td id="T_35680_row2_col1" class="data row2 col1" >0.002074</td>
#       <td id="T_35680_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_35680_row2_col3" class="data row2 col3" >0.999311</td>
#       <td id="T_35680_row2_col4" class="data row2 col4" >0.054149</td>
#       <td id="T_35680_row2_col5" class="data row2 col5" >0.045730</td>
#       <td id="T_35680_row2_col6" class="data row2 col6" >0.998093</td>
#       <td id="T_35680_row2_col7" class="data row2 col7" >0.003548</td>
#       <td id="T_35680_row2_col8" class="data row2 col8" >0.014309</td>
#       <td id="T_35680_row2_col9" class="data row2 col9" >0.029997</td>
#       <td id="T_35680_row2_col10" class="

# %%
def corr_chart(df_corr):
    corr=df_corr.corr()
    #screen top half to get a triangle
    top = np.zeros_like(corr, dtype=np.bool)
    top[np.triu_indices_from(top)] = True
    fig=plt.figure()
    fig, ax = plt.subplots(figsize=(12,12))
    sns.heatmap(corr, mask=top, cmap='coolwarm', 
        center = 0, square=True, 
        linewidths=.5, cbar_kws={'shrink':.5}, 
        annot = True, annot_kws={'size': 9}, fmt = '.3f')           
    plt.xticks(rotation=45) # rotate variable labels on columns (x axis)
    plt.yticks(rotation=0) # use horizontal variable labels on rows (y axis)
    plt.title('Correlation Heat Map')   
    plt.savefig('plot-corr-map.pdf', 
        bbox_inches = 'tight', dpi=None, facecolor='w', edgecolor='b', 
        orientation='portrait', papertype=None, format=None, 
        transparent=True, pad_inches=0.25, frameon=None)      

np.set_printoptions(precision=3)

# examine correlations
corr_chart(df_corr = data)

# %%
sns.countplot(x = 'class', data = data)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
#Investigating UGRIZ

ugriz = data[['u','g','r','i','z']]
ugriz.hist(figsize= (10,6))

data[['u','g','r','i','z']].describe()
# Out:
#                    u              g              r              i  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       21.980468      20.531387      19.645762      19.084854
# std        31.769291      31.750292       1.854760       1.757895
# min     -9999.000000   -9999.000000       9.822070       9.469903
# 25%        20.352353      18.965230      18.135828      17.732285
# 50%        22.179135      21.099835      20.125290      19.405145
# 75%        23.687440      22.123767      21.044785      20.396495
# max        32.781390      31.602240      29.571860      32.141470
#
#                    z
# count  100000.000000
# mean       18.668810
# std        31.728152
# min     -9999.000000
# 25%        17.460677
# 50%        19.004595
# 75%        19.921120
# max        29.383740

# %% [markdown]
# ### We Probably Need to Scale tihs part of the data

# %%
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MinMaxScaler

#Going to scale UGRIZ columns. 
mms = MinMaxScaler()

data[['u','g','r','i','z']] = mms.fit_transform(data[['u','g','r','i','z']])

# %%
data[['u','g','r','i','z']].describe()
# Out:
#                    u              g              r              i  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.998923       0.998896       0.497407       0.424097
# std         0.003167       0.003165       0.093913       0.077537
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.998761       0.998740       0.420954       0.364438
# 50%         0.998943       0.998953       0.521688       0.438225
# 75%         0.999093       0.999055       0.568245       0.481951
# max         1.000000       1.000000       1.000000       1.000000
#
#                    z
# count  100000.000000
# mean        0.998932
# std         0.003164
# min         0.000000
# 25%         0.998811
# 50%         0.998965
# 75%         0.999056
# max         1.000000

# %%
data['class'].value_counts()
# Out:
# GALAXY    59445
# STAR      21594
# QSO       18961
# Name: class, dtype: int64

# %% [markdown]
# # Random Forest and Gradient Boost just to see

# %% [markdown]
# #### Random Forest

# %%
#Make Classes Numeric before training model

data['class'].replace(['GALAXY', 'STAR','QSO'],
                        [0, 1,2], inplace=True)

# %%
data['class'].value_counts()
# Out:
# 0    59445
# 1    21594
# 2    18961
# Name: class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import sklearn.metrics as metrics
from sklearn.metrics import classification_report

X = data.drop(columns = ['class'])
y = data['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
#Random Forest 

def classifier_model(model):
    classifier = model()
    classifier.fit(X_train,y_train)
    y_pred = classifier.predict(X_test)
    acc = round(classifier.score(X_test,y_test) * 100, 2)
    print(classification_report(y_test, y_pred))
    print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))
    print("MAE: ", mean_absolute_error(y_test,y_pred))
    print(str(acc) + ' percent')
    return classifier   

classifier_model(RandomForestClassifier)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     14927
#            1       0.99      1.00      1.00      5351
#            2       0.97      0.92      0.94      4722
#
#     accuracy                           0.98     25000
#    macro avg       0.98      0.97      0.97     25000
# weighted avg       0.98      0.98      0.98     25000
#
# RMSE:  0.290516780926679
# MAE:  0.04288
# 97.79 percent
# RandomForestClassifier()

# %%
#Confusion Matrix for RF
from sklearn.metrics import confusion_matrix


clf = RandomForestClassifier().fit(X_train,y_train)
clf.predict(X_train)
y_pred = clf.predict(X_test)


cm = confusion_matrix(y_test, y_pred)

cm_df = pd.DataFrame(cm,
                     index = ['GALAXY','STAR','QSO'], 
                     columns = ['GALAXY','STAR','QSO'])

#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True,  cmap="YlGnBu")
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# #### Gradient Boost

# %%
#Gradient Boost

def classifier_model(model):
    classifier = model()
    classifier.fit(X_train,y_train)
    y_pred = classifier.predict(X_test)
    acc = round(classifier.score(X_test,y_test) * 100, 2)
    print(classification_report(y_test, y_pred))
    print("RMSE: ", np.sqrt(mean_squared_error(y_test, y_pred)))
    print("MAE: ", mean_absolute_error(y_test,y_pred))
    print(str(acc) + ' percent')
    return classifier   

classifier_model(GradientBoostingClassifier)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     14927
#            1       1.00      1.00      1.00      5351
#            2       0.97      0.91      0.94      4722
#
#     accuracy                           0.98     25000
#    macro avg       0.98      0.97      0.97     25000
# weighted avg       0.98      0.98      0.98     25000
#
# RMSE:  0.3044339008717656
# MAE:  0.047
# 97.58 percent
# GradientBoostingClassifier()

# %%
#Confusion Matrix for GB
from sklearn.metrics import confusion_matrix


gb_clf = GradientBoostingClassifier().fit(X_train,y_train)
gb_clf.predict(X_train)
y_pred = gb_clf.predict(X_test)


cm = confusion_matrix(y_test, y_pred)

cm_df = pd.DataFrame(cm,
                     index = ['GALAXY','STAR','QSO'], 
                     columns = ['GALAXY','STAR','QSO'])

#Plotting the confusion matrix
plt.figure(figsize=(5,4))
sns.heatmap(cm_df, annot=True,  cmap="YlGnBu")
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
